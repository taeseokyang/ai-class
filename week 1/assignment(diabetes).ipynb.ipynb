# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ### CSV 파일 불러오기

# %%
df = pd.read_csv("diabetes.csv", index_col=0)
df
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 6                148             72             35        0  33.6
# 1                 85             66             29        0  26.6
# 8                183             64              0        0  23.3
# 1                 89             66             23       94  28.1
# 0                137             40             35      168  43.1
# ...              ...            ...            ...      ...   ...
# 10               101             76             48      180  32.9
# 2                122             70             27        0  36.8
# 5                121             72             23      112  26.2
# 1                126             60              0        0  30.1
# 1                 93             70             31        0  30.4
#
#              DiabetesPedigreeFunction  Age  Outcome
# Pregnancies
# 6                               0.627   50        1
# 1                               0.351   31        0
# 8                               0.672   32        1
# 1                               0.167   21        0
# 0                               2.288   33        1
# ...                               ...  ...      ...
# 10                              0.171   63        0
# 2                               0.340   27        0
# 5                               0.245   30        0
# 1                               0.349   47        1
# 1                               0.315   23        0
#
# [768 rows x 8 columns]

# %% [markdown]
# # 1. 당뇨병 데이터를 가지고 머신러닝 5가지 분류를 수행.

# %% [markdown]
# ### 데이터 전처리

# %%
df.columns
# Out:
# Index(['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
sns.countplot(data = df, x="Outcome")
plt.xlabel("Diabete or Not")
plt.ylabel("Count")
plt.title("Label")
# Out:
# Text(0.5, 1.0, 'Label')

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
(df == 0).sum()
# Out:
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %%
cols_to_check = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI',
       'DiabetesPedigreeFunction', 'Age']
df = df[df[cols_to_check].ne(0).all(axis=1)]
df
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 1                 89             66             23       94  28.1
# 0                137             40             35      168  43.1
# 3                 78             50             32       88  31.0
# 2                197             70             45      543  30.5
# 1                189             60             23      846  30.1
# ...              ...            ...            ...      ...   ...
# 0                181             88             44      510  43.3
# 1                128             88             39      110  36.5
# 2                 88             58             26       16  28.4
# 10               101             76             48      180  32.9
# 5                121             72             23      112  26.2
#
#              DiabetesPedigreeFunction  Age  Outcome
# Pregnancies
# 1                               0.167   21        0
# 0                               2.288   33        1
# 3                               0.248   26        1
# 2                               0.158   53        1
# 1                               0.398   59        1
# ...                               ...  ...      ...
# 0                               0.222   26        1
# 1                               1.057   37        1
# 2                               0.766   22        0
# 10                              0.171   63        0
# 5                               0.245   30        0
#
# [392 rows x 8 columns]

# %%
(df == 0).sum()
# Out:
# Glucose                       0
# BloodPressure                 0
# SkinThickness                 0
# Insulin                       0
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     262
# dtype: int64

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    262
# 1    130
# Name: count, dtype: int64

# %%
sns.pairplot(df,
             vars=['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI',
       'DiabetesPedigreeFunction', 'Age'],
            hue ='Outcome')
plt.show()

# %%
X=df.drop('Outcome',axis=1)
X.head()
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 1                 89             66             23       94  28.1
# 0                137             40             35      168  43.1
# 3                 78             50             32       88  31.0
# 2                197             70             45      543  30.5
# 1                189             60             23      846  30.1
#
#              DiabetesPedigreeFunction  Age
# Pregnancies
# 1                               0.167   21
# 0                               2.288   33
# 3                               0.248   26
# 2                               0.158   53
# 1                               0.398   59

# %%
y=df['Outcome']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### SVM 분류

# %%
clf_svm = SVC(random_state=0)
clf_svm.fit(X_train, y_train)

pred_svm = clf_svm.predict(X_test)

print("\n--- SVM Classifier ---")
print(accuracy_score(y_test, pred_svm))
print(confusion_matrix(y_test, pred_svm))
# Out:
# --- SVM Classifier ---
# 0.7755102040816326
# [[60  5]
#  [17 16]]

# %% [markdown]
# ### LR 분류

# %%
clf_lr = LogisticRegression(random_state=0)
clf_lr.fit(X_train, y_train)

pred_lr = clf_lr.predict(X_test)

print ("\n--- Logistic Regression Classifier ---")
print (accuracy_score(y_test, pred_lr))
print (confusion_matrix(y_test, pred_lr))
# Out:
# --- Logistic Regression Classifier ---
# 0.8061224489795918
# [[61  4]
#  [15 18]]

# %% [markdown]
# ### KNN 분류

# %%
clf_knn = KNeighborsClassifier(n_neighbors=5)
clf_knn.fit(X_train, y_train)
pred_knn = clf_knn.predict(X_test)
print("\n--- KNN Classifier ---")
print(accuracy_score(y_test, pred_knn))
print(confusion_matrix(y_test, pred_knn))
# Out:
# --- KNN Classifier ---
# 0.7448979591836735
# [[55 10]
#  [15 18]]

# %% [markdown]
# ### DT 분류

# %%
clf_dt = DecisionTreeClassifier(random_state=0)
clf_dt.fit(X_train, y_train)

pred_dt = clf_dt.predict(X_test)

print ("\n--- Decision Tree Classifier ---")
print (accuracy_score(y_test, pred_dt))
print (confusion_matrix(y_test, pred_dt))
# Out:
# --- Decision Tree Classifier ---
# 0.7448979591836735
# [[54 11]
#  [14 19]]

# %% [markdown]
# ### RF 분류

# %%
print ("\n--- Radom Forest ---")
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train, y_train)
pred = rf_clf.predict(X_test)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test, pred))
# Out:
# --- Radom Forest ---
# 0.7857142857142857
# [[58  7]
#  [14 19]]

# %% [markdown]
# ## 2. 동일한 데이터로 딥러닝 분류 수행하라. (dense layer 만 사용)

# %%
y=df['Outcome']
Y = pd.get_dummies(y).values

# %%
X=df.drop('Outcome',axis=1)
X = X.values
X
# Out:
# array([[ 89.   ,  66.   ,  23.   , ...,  28.1  ,   0.167,  21.   ],
#        [137.   ,  40.   ,  35.   , ...,  43.1  ,   2.288,  33.   ],
#        [ 78.   ,  50.   ,  32.   , ...,  31.   ,   0.248,  26.   ],
#        ...,
#        [ 88.   ,  58.   ,  26.   , ...,  28.4  ,   0.766,  22.   ],
#        [101.   ,  76.   ,  48.   , ...,  32.9  ,   0.171,  63.   ],
#        [121.   ,  72.   ,  23.   , ...,  26.2  ,   0.245,  30.   ]])

# %%
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam

model = Sequential()

model.add(Dense(10,input_shape=(7,),activation='tanh'))
model.add(Dense(8,activation='tanh'))
model.add(Dense(6,activation='tanh'))
model.add(Dense(2,activation='softmax'))

model.compile(Adam(learning_rate=0.0001),'binary_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 10)                80
#
#  dense_13 (Dense)            (None, 8)                 88
#
#  dense_14 (Dense)            (None, 6)                 54
#
#  dense_15 (Dense)            (None, 2)                 14
#
# =================================================================
# Total params: 236
# Trainable params: 236
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=40, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/40
# 10/10 [==============================] - 1s 11ms/step - loss: 0.7320 - accuracy: 0.4760 - val_loss: 0.7390 - val_accuracy: 0.3924
# Epoch 2/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7290 - accuracy: 0.4760 - val_loss: 0.7357 - val_accuracy: 0.3924
# Epoch 3/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7261 - accuracy: 0.4888 - val_loss: 0.7326 - val_accuracy: 0.4051
# Epoch 4/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7234 - accuracy: 0.4888 - val_loss: 0.7295 - val_accuracy: 0.4177
# Epoch 5/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7207 - accuracy: 0.4920 - val_loss: 0.7265 - val_accuracy: 0.4304
# Epoch 6/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7182 - accuracy: 0.4952 - val_loss: 0.7239 - val_accuracy: 0.4304
# Epoch 7/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7158 - accuracy: 0.4920 - val_loss: 0.7212 - val_accuracy: 0.4430
# Epoch 8/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7135 - accuracy: 0.4952 - val_loss: 0.7189 - val_accuracy: 0.4430
# Epoch 9/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7114 - accuracy: 0.4952 - val_loss: 0.7164 - val_accuracy: 0.4430
# Epoch 10/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7093 - accuracy: 0.4984 - val_loss: 0.7140 - val_accuracy: 0.4430
# Epoch 11/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7073 - accuracy: 0.5016 - val_loss: 0.7115 - val_accuracy: 0.4430
# Epoch 12/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7053 - accuracy: 0.5016 - val_loss: 0.7091 - val_accuracy: 0.4430
# Epoch 13/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7032 - accuracy: 0.5048 - val_loss: 0.7068 - val_accuracy: 0.4430
# Epoch 14/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7012 - accuracy: 0.5080 - val_loss: 0.7043 - val_accuracy: 0.4430
# Epoch 15/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6989 - accuracy: 0.5144 - val_loss: 0.7021 - val_accuracy: 0.4557
# Epoch 16/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6970 - accuracy: 0.5080 - val_loss: 0.6997 - val_accuracy: 0.4810
# Epoch 17/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6949 - accuracy: 0.5112 - val_loss: 0.6977 - val_accuracy: 0.5063
# Epoch 18/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6930 - accuracy: 0.5431 - val_loss: 0.6956 - val_accuracy: 0.6835
# Epoch 19/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6913 - accuracy: 0.6645 - val_loss: 0.6937 - val_accuracy: 0.6835
# Epoch 20/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6896 - accuracy: 0.6645 - val_loss: 0.6919 - val_accuracy: 0.6835
# Epoch 21/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6880 - accuracy: 0.6645 - val_loss: 0.6900 - val_accuracy: 0.6835
# Epoch 22/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6864 - accuracy: 0.6645 - val_loss: 0.6882 - val_accuracy: 0.6835
# Epoch 23/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6848 - accuracy: 0.6645 - val_loss: 0.6864 - val_accuracy: 0.6835
# Epoch 24/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6832 - accuracy: 0.6645 - val_loss: 0.6844 - val_accuracy: 0.6835
# Epoch 25/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6815 - accuracy: 0.6645 - val_loss: 0.6825 - val_accuracy: 0.6835
# Epoch 26/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6798 - accuracy: 0.6645 - val_loss: 0.6806 - val_accuracy: 0.6835
# Epoch 27/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6780 - accuracy: 0.6645 - val_loss: 0.6788 - val_accuracy: 0.6835
# Epoch 28/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6764 - accuracy: 0.6645 - val_loss: 0.6768 - val_accuracy: 0.6835
# Epoch 29/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6746 - accuracy: 0.6645 - val_loss: 0.6748 - val_accuracy: 0.6835
# Epoch 30/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6729 - accuracy: 0.6645 - val_loss: 0.6728 - val_accuracy: 0.6835
# Epoch 31/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6711 - accuracy: 0.6645 - val_loss: 0.6708 - val_accuracy: 0.6835
# Epoch 32/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6693 - accuracy: 0.6645 - val_loss: 0.6687 - val_accuracy: 0.6835
# Epoch 33/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6675 - accuracy: 0.6645 - val_loss: 0.6667 - val_accuracy: 0.6835
# Epoch 34/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6657 - accuracy: 0.6645 - val_loss: 0.6647 - val_accuracy: 0.6835
# Epoch 35/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6643 - accuracy: 0.6645 - val_loss: 0.6622 - val_accuracy: 0.6835
# Epoch 36/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6623 - accuracy: 0.6645 - val_loss: 0.6602 - val_accuracy: 0.6835
# Epoch 37/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6609 - accuracy: 0.6645 - val_loss: 0.6584 - val_accuracy: 0.6835
# Epoch 38/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6593 - accuracy: 0.6645 - val_loss: 0.6566 - val_accuracy: 0.6835
# Epoch 39/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6580 - accuracy: 0.6645 - val_loss: 0.6546 - val_accuracy: 0.6835
# Epoch 40/40
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6567 - accuracy: 0.6645 - val_loss: 0.6528 - val_accuracy: 0.6835
# 3/3 [==============================] - 0s 890us/step

# %%
loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      1.00      0.81        54
#            1       0.00      0.00      0.00        25
#
#     accuracy                           0.68        79
#    macro avg       0.34      0.50      0.41        79
# weighted avg       0.47      0.68      0.56        79
#
# [[54  0]
#  [25  0]]

# %% [markdown]
# ## 3. 해당 데이터에서 Outcome을 삭제하고 BMI를 예측하는 회귀를 수행하라.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
df_corr=df.corr()

#히트맵
plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %%
X = df.drop(['Outcome', 'BMI'], axis=1)
y = df['BMI']
y.head()
# Out:
# Pregnancies
# 1    28.1
# 0    43.1
# 3    31.0
# 2    30.5
# 1    30.1
# Name: BMI, dtype: float64

# %%
X
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin  \
# Pregnancies
# 1                 89             66             23       94
# 0                137             40             35      168
# 3                 78             50             32       88
# 2                197             70             45      543
# 1                189             60             23      846
# ...              ...            ...            ...      ...
# 0                181             88             44      510
# 1                128             88             39      110
# 2                 88             58             26       16
# 10               101             76             48      180
# 5                121             72             23      112
#
#              DiabetesPedigreeFunction  Age
# Pregnancies
# 1                               0.167   21
# 0                               2.288   33
# 3                               0.248   26
# 2                               0.158   53
# 1                               0.398   59
# ...                               ...  ...
# 0                               0.222   26
# 1                               1.057   37
# 2                               0.766   22
# 10                              0.171   63
# 5                               0.245   30
#
# [392 rows x 6 columns]

# %%
X_train, X_test, y_train, y_test=train_test_split(X,
                                                  y,
                                                  test_size=0.2,
                                                  shuffle=True,
                                                  random_state=12)

# %% [markdown]
# ### Linear 회귀

# %%
model = LinearRegression()
model.fit(X_train, y_train)
ly_preds = model.predict(X_test)

def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)
def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error
    
print('평균제곱근오차', mean_squared_error(ly_preds, y_test))
print('평균제곱근오차', mse_np(ly_preds, y_test))
print('평균제곱근오차', mse(ly_preds, y_test))
# Out:
# 평균제곱근오차 26.065002101784696
# 평균제곱근오차 26.065002101784696
# 평균제곱근오차 26.06500210178469

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_test['SkinThickness'], y_test, label='y_test')
plt.scatter(X_test['SkinThickness'], ly_preds, c='g', label='ly_preds')
plt.show()

# %% [markdown]
# ### Decision Tree 회귀

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(X_train, y_train)

dy_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(dy_preds, y_test))
# Out:
# 평균제곱근오차 56.74430379746833

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_test['SkinThickness'], y_test, label='y_test')
plt.scatter(X_test['SkinThickness'], dy_preds, c='g', label='dy_preds')
plt.show()

# %% [markdown]
# ### Random Forest 회귀

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)
ry_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))
# Out:
# 평균제곱근오차 35.88865694936714

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_test['SkinThickness'], y_test, label='y_test')
plt.scatter(X_test['SkinThickness'], ry_preds, c='g', label='ry_preds')
plt.show()

# %% [markdown]
# ### SVR 회귀

# %%
from sklearn.svm import SVR

model = SVR(kernel='linear')
model.fit(X_train, y_train)
ry_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))
# Out:
# 평균제곱근오차 26.04096085162074

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_test['SkinThickness'], y_test, label='y_test')
plt.scatter(X_test['SkinThickness'], ry_preds, c='g', label='ly_preds')
plt.show()

# %% [markdown]
# ## 4. 3번과 동일하지만 dense layer만 사용한 신경만으로 회귀를 수행하라.

# %%
y = df['BMI']
Y = pd.get_dummies(y).values
Y
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
X = df.drop(['Outcome', 'BMI'], axis=1)
X = X.values
X
# Out:
# array([[8.900e+01, 6.600e+01, 2.300e+01, 9.400e+01, 1.670e-01, 2.100e+01],
#        [1.370e+02, 4.000e+01, 3.500e+01, 1.680e+02, 2.288e+00, 3.300e+01],
#        [7.800e+01, 5.000e+01, 3.200e+01, 8.800e+01, 2.480e-01, 2.600e+01],
#        ...,
#        [8.800e+01, 5.800e+01, 2.600e+01, 1.600e+01, 7.660e-01, 2.200e+01],
#        [1.010e+02, 7.600e+01, 4.800e+01, 1.800e+02, 1.710e-01, 6.300e+01],
#        [1.210e+02, 7.200e+01, 2.300e+01, 1.120e+02, 2.450e-01, 3.000e+01]])

# %%
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam

model = Sequential()

model.add(Dense(8,input_shape=(6,),activation='tanh'))
model.add(Dense(30,activation='tanh'))
model.add(Dense(30,activation='tanh'))
model.add(Dense(1))

model.compile(optimizer = 'rmsprop', loss = 'mse', metrics = ['mse'])

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 8)                 56
#
#  dense_17 (Dense)            (None, 30)                270
#
#  dense_18 (Dense)            (None, 30)                930
#
#  dense_19 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 1,287
# Trainable params: 1,287
# Non-trainable params: 0
# _________________________________________________________________

# %%
N_EPOCHS = 20

history=model.fit(x=X_train, y=y_train, epochs=N_EPOCHS, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)
# Out:
# Epoch 1/20
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 2/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 3/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 4/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 5/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 6/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 7/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 8/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 9/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 10/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 11/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 12/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 13/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 14/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 15/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 16/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 17/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 18/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 19/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 20/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0079 - val_mse: 0.0079
# 3/3 [==============================] - 0s 976us/step

# %%
plt.figure(figsize=(10,7))
plt.plot(range(N_EPOCHS), history.history['loss'], label='train loss')
plt.plot(range(N_EPOCHS), history.history['val_loss'], label='test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0079 - mse: 0.0079
# [0.007930920459330082, 0.007930920459330082]
