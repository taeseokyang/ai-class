# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# 2024-10-21 21:07:48.404658: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### CSV 파일 불러오기

# %%
df = pd.read_csv("datas/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# # 1. 당뇨병 데이터를 가지고 머신러닝 5가지 분류를 수행.

# %% [markdown]
# ### 데이터 전처리

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
sns.countplot(data = df, x="Outcome")
plt.xlabel("Diabete or Not")
plt.ylabel("Count")
plt.title("Label")
# Out:
# Text(0.5, 1.0, 'Label')

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df_majority = df[df['Outcome'] == 0]
df_minority = df[df['Outcome'] == 1]

df_majority_downsampled = df_majority.sample(len(df_minority), random_state=42)

df = pd.concat([df_majority_downsampled, df_minority])
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    268
# 1    268
# Name: count, dtype: int64

# %%
df.hist(bins=100, figsize=(10, 5))
plt.tight_layout()
plt.show()

# %%
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.115253       0.114106      -0.093456
# Glucose                      0.115253  1.000000       0.128715       0.053073
# BloodPressure                0.114106  0.128715       1.000000       0.190621
# SkinThickness               -0.093456  0.053073       0.190621       1.000000
# Insulin                     -0.033224  0.325281       0.086800       0.448939
# BMI                          0.005954  0.197743       0.244144       0.366816
# DiabetesPedigreeFunction    -0.057325  0.125992       0.040177       0.208554
# Age                          0.512950  0.292035       0.238305      -0.095770
# Outcome                      0.219760  0.488653       0.074021       0.097215
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.033224  0.005954                 -0.057325
# Glucose                   0.325281  0.197743                  0.125992
# BloodPressure             0.086800  0.244144                  0.040177
# SkinThickness             0.448939  0.366816                  0.208554
# Insulin                   1.000000  0.149096                  0.190043
# BMI                       0.149096  1.000000                  0.152147
# DiabetesPedigreeFunction  0.190043  0.152147                  1.000000
# Age                       0.029943  0.025454                  0.010838
# Outcome                   0.170363  0.325308                  0.149907
#
#                                Age   Outcome
# Pregnancies               0.512950  0.219760
# Glucose                   0.292035  0.488653
# BloodPressure             0.238305  0.074021
# SkinThickness            -0.095770  0.097215
# Insulin                   0.029943  0.170363
# BMI                       0.025454  0.325308
# DiabetesPedigreeFunction  0.010838  0.149907
# Age                       1.000000  0.265398
# Outcome                   0.265398  1.000000

# %%
def remove_outliers(df, columns):
    for column in columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        df = df[(df[column] >= (Q1 - 1.5 * IQR)) & (df[column] <= (Q3 + 1.5 * IQR))]
    return df
columns_to_check = ['Glucose', 'BMI']
df = remove_outliers(df, columns_to_check)

df[columns_to_check].hist(bins=100, figsize=(10, 5))
plt.tight_layout()
plt.show()

# %%
# threshold = int(len(df) * 0.95)
# df_sorted = df.sort_values(by='Insulin')
# df = df_sorted.iloc[:threshold]
# df[columns_to_check].hist(bins=100, figsize=(10, 5))
# plt.tight_layout()
# plt.show()

# %%
(df == 0).sum()
# Out:
# Pregnancies                  59
# Glucose                       0
# BloodPressure                19
# SkinThickness               158
# Insulin                     255
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     259
# dtype: int64

# %%
def replace_zeros_with_mean(df, cols):
    for col in cols:
        df[col].replace(0, df[col].mean(), inplace=True)
    return df

df = replace_zeros_with_mean(df, columns_to_check)
df[columns_to_check].hist(bins=100, figsize=(10, 5))
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df,
             vars=columns_to_check,
            hue ='Outcome')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

X = df[columns_to_check]
scaler = MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X.hist(bins=100, figsize=(10, 5))
plt.tight_layout()
plt.show()

# %%
y=df['Outcome']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### SVM 분류

# %%
clf_svm = SVC(random_state=0)
clf_svm.fit(X_train, y_train)

pred_svm = clf_svm.predict(X_test)

print("\n--- SVM Classifier ---")
print(accuracy_score(y_test, pred_svm))
print(confusion_matrix(y_test, pred_svm))
# Out:
# --- SVM Classifier ---
# 0.7286821705426356
# [[45 19]
#  [16 49]]

# %% [markdown]
# ### LR 분류

# %%
clf_lr = LogisticRegression(random_state=0)
clf_lr.fit(X_train, y_train)

pred_lr = clf_lr.predict(X_test)

print ("\n--- Logistic Regression Classifier ---")
print (accuracy_score(y_test, pred_lr))
print (confusion_matrix(y_test, pred_lr))
# Out:
# --- Logistic Regression Classifier ---
# 0.751937984496124
# [[47 17]
#  [15 50]]

# %% [markdown]
# ### KNN 분류

# %%
clf_knn = KNeighborsClassifier(n_neighbors=5)
clf_knn.fit(X_train, y_train)
pred_knn = clf_knn.predict(X_test)
print("\n--- KNN Classifier ---")
print(accuracy_score(y_test, pred_knn))
print(confusion_matrix(y_test, pred_knn))
# Out:
# --- KNN Classifier ---
# 0.6744186046511628
# [[43 21]
#  [21 44]]

# %% [markdown]
# ### DT 분류

# %%
clf_dt = DecisionTreeClassifier(random_state=0)
clf_dt.fit(X_train, y_train)

pred_dt = clf_dt.predict(X_test)

print ("\n--- Decision Tree Classifier ---")
print (accuracy_score(y_test, pred_dt))
print (confusion_matrix(y_test, pred_dt))
# Out:
# --- Decision Tree Classifier ---
# 0.6976744186046512
# [[42 22]
#  [17 48]]

# %% [markdown]
# ### RF 분류

# %%
print ("\n--- Radom Forest ---")
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train, y_train)
pred = rf_clf.predict(X_test)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test, pred))
# Out:
# --- Radom Forest ---
# 0.7131782945736435
# [[43 21]
#  [16 49]]

# %% [markdown]
# ## 2. 동일한 데이터로 딥러닝 분류 수행하라. (dense layer 만 사용)

# %%
Y = pd.get_dummies(y).values

# %%
X = X.values
X
# Out:
# array([[0.28169014, 0.63987138],
#        [0.14788732, 0.49839228],
#        [0.38028169, 0.36334405],
#        ...,
#        [0.93661972, 0.5562701 ],
#        [0.79577465, 0.82958199],
#        [0.48591549, 0.38263666]])

# %%
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam

model = Sequential()

model.add(Dense(10,input_shape=(2,),activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(2,activation='sigmoid'))

model.compile(Adam(learning_rate=0.0001),'binary_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# 2024-10-21 21:33:18.684078: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                30
#
#  dense_1 (Dense)             (None, 8)                 88
#
#  dense_2 (Dense)             (None, 6)                 54
#
#  dense_3 (Dense)             (None, 2)                 14
#
# =================================================================
# Total params: 186
# Trainable params: 186
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=40, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/40
# 13/13 [==============================] - 2s 21ms/step - loss: 0.6917 - accuracy: 0.4964 - val_loss: 0.6894 - val_accuracy: 0.5243
# Epoch 2/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6911 - accuracy: 0.4964 - val_loss: 0.6888 - val_accuracy: 0.5243
# Epoch 3/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6906 - accuracy: 0.4964 - val_loss: 0.6882 - val_accuracy: 0.5243
# Epoch 4/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6901 - accuracy: 0.4964 - val_loss: 0.6876 - val_accuracy: 0.5243
# Epoch 5/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6896 - accuracy: 0.4988 - val_loss: 0.6870 - val_accuracy: 0.5340
# Epoch 6/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6891 - accuracy: 0.5061 - val_loss: 0.6864 - val_accuracy: 0.5340
# Epoch 7/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6886 - accuracy: 0.5085 - val_loss: 0.6858 - val_accuracy: 0.5437
# Epoch 8/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6881 - accuracy: 0.5207 - val_loss: 0.6853 - val_accuracy: 0.5534
# Epoch 9/40
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6875 - accuracy: 0.5280 - val_loss: 0.6847 - val_accuracy: 0.5631
# Epoch 10/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6870 - accuracy: 0.5304 - val_loss: 0.6841 - val_accuracy: 0.5631
# Epoch 11/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6865 - accuracy: 0.5255 - val_loss: 0.6836 - val_accuracy: 0.5728
# Epoch 12/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6860 - accuracy: 0.5304 - val_loss: 0.6829 - val_accuracy: 0.5728
# Epoch 13/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6854 - accuracy: 0.5377 - val_loss: 0.6824 - val_accuracy: 0.5825
# Epoch 14/40
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6848 - accuracy: 0.5426 - val_loss: 0.6819 - val_accuracy: 0.5825
# Epoch 15/40
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6843 - accuracy: 0.5572 - val_loss: 0.6813 - val_accuracy: 0.5825
# Epoch 16/40
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6837 - accuracy: 0.5596 - val_loss: 0.6807 - val_accuracy: 0.5922
# Epoch 17/40
# 13/13 [==============================] - 0s 8ms/step - loss: 0.6831 - accuracy: 0.5669 - val_loss: 0.6802 - val_accuracy: 0.5825
# Epoch 18/40
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6825 - accuracy: 0.5718 - val_loss: 0.6796 - val_accuracy: 0.5825
# Epoch 19/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6819 - accuracy: 0.5766 - val_loss: 0.6791 - val_accuracy: 0.5728
# Epoch 20/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6814 - accuracy: 0.5791 - val_loss: 0.6786 - val_accuracy: 0.5825
# Epoch 21/40
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6807 - accuracy: 0.5888 - val_loss: 0.6780 - val_accuracy: 0.5825
# Epoch 22/40
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6802 - accuracy: 0.5888 - val_loss: 0.6776 - val_accuracy: 0.6019
# Epoch 23/40
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6795 - accuracy: 0.5985 - val_loss: 0.6770 - val_accuracy: 0.6019
# Epoch 24/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6788 - accuracy: 0.6058 - val_loss: 0.6765 - val_accuracy: 0.6019
# Epoch 25/40
# 13/13 [==============================] - 0s 10ms/step - loss: 0.6782 - accuracy: 0.6034 - val_loss: 0.6759 - val_accuracy: 0.6019
# Epoch 26/40
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6776 - accuracy: 0.6034 - val_loss: 0.6753 - val_accuracy: 0.6214
# Epoch 27/40
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6769 - accuracy: 0.6107 - val_loss: 0.6748 - val_accuracy: 0.6214
# Epoch 28/40
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6763 - accuracy: 0.6131 - val_loss: 0.6742 - val_accuracy: 0.6214
# Epoch 29/40
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6757 - accuracy: 0.6156 - val_loss: 0.6736 - val_accuracy: 0.6117
# Epoch 30/40
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6751 - accuracy: 0.6204 - val_loss: 0.6731 - val_accuracy: 0.6214
# Epoch 31/40
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6744 - accuracy: 0.6204 - val_loss: 0.6725 - val_accuracy: 0.6214
# Epoch 32/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6739 - accuracy: 0.6277 - val_loss: 0.6720 - val_accuracy: 0.6311
# Epoch 33/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6732 - accuracy: 0.6326 - val_loss: 0.6713 - val_accuracy: 0.6311
# Epoch 34/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6726 - accuracy: 0.6302 - val_loss: 0.6707 - val_accuracy: 0.6311
# Epoch 35/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6721 - accuracy: 0.6302 - val_loss: 0.6701 - val_accuracy: 0.6311
# Epoch 36/40
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6715 - accuracy: 0.6302 - val_loss: 0.6695 - val_accuracy: 0.6311
# Epoch 37/40
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6708 - accuracy: 0.6326 - val_loss: 0.6689 - val_accuracy: 0.6214
# Epoch 38/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6703 - accuracy: 0.6375 - val_loss: 0.6683 - val_accuracy: 0.6214
# Epoch 39/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6697 - accuracy: 0.6399 - val_loss: 0.6677 - val_accuracy: 0.6117
# Epoch 40/40
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6691 - accuracy: 0.6399 - val_loss: 0.6671 - val_accuracy: 0.6117
# 4/4 [==============================] - 0s 1ms/step

# %%
loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.32      0.44        50
#            1       0.58      0.89      0.70        53
#
#     accuracy                           0.61       103
#    macro avg       0.65      0.60      0.57       103
# weighted avg       0.65      0.61      0.58       103
#
# [[16 34]
#  [ 6 47]]

# %% [markdown]
# ## 3. 해당 데이터에서 Outcome을 삭제하고 BMI를 예측하는 회귀를 수행하라.

# %%
df = pd.read_csv("datas/diabetes.csv", index_col=0)
df
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 6                148             72             35        0  33.6
# 1                 85             66             29        0  26.6
# 8                183             64              0        0  23.3
# 1                 89             66             23       94  28.1
# 0                137             40             35      168  43.1
# ...              ...            ...            ...      ...   ...
# 10               101             76             48      180  32.9
# 2                122             70             27        0  36.8
# 5                121             72             23      112  26.2
# 1                126             60              0        0  30.1
# 1                 93             70             31        0  30.4
#
#              DiabetesPedigreeFunction  Age  Outcome
# Pregnancies
# 6                               0.627   50        1
# 1                               0.351   31        0
# 8                               0.672   32        1
# 1                               0.167   21        0
# 0                               2.288   33        1
# ...                               ...  ...      ...
# 10                              0.171   63        0
# 2                               0.340   27        0
# 5                               0.245   30        0
# 1                               0.349   47        1
# 1                               0.315   23        0
#
# [768 rows x 8 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
df_corr=df.corr()

plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %%
columns_to_check = ['SkinThickness', 'BloodPressure']

df[columns_to_check].hist(bins=50, figsize=(10, 5))
plt.tight_layout()
plt.show()

# %%
def remove_outliers(df, columns):
    for column in columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        df = df[(df[column] >= (Q1 - 1.5 * IQR)) & (df[column] <= (Q3 + 1.5 * IQR))]
    return df

df = remove_outliers(df, columns_to_check)
df = df[df['SkinThickness'] != 0]

df[columns_to_check].hist(bins=50, figsize=(10, 5))
plt.tight_layout()
plt.show()

# %%
X = df[columns_to_check]
scaler = MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X.hist(bins=100, figsize=(10, 5))
plt.tight_layout()
plt.show()

# %%
y = df['BMI']
y.head()
# Out:
# Pregnancies
# 6    33.6
# 1    26.6
# 1    28.1
# 0    43.1
# 3    31.0
# Name: BMI, dtype: float64

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2,shuffle=True,random_state=12)

# %% [markdown]
# ### Linear 회귀

# %%
model = LinearRegression()
model.fit(X_train, y_train)
ly_preds = model.predict(X_test)

    
print('평균제곱근오차', mean_squared_error(ly_preds, y_test))
# Out:
# 평균제곱근오차 28.033482177140808

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_test['SkinThickness'], y_test, label='y_test')
plt.scatter(X_test['SkinThickness'], ly_preds, c='g', label='ly_preds')
plt.show()

# %% [markdown]
# ### Decision Tree 회귀

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(X_train, y_train)

dy_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(dy_preds, y_test))
# Out:
# 평균제곱근오차 49.480098650051936

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_test['SkinThickness'], y_test, label='y_test')
plt.scatter(X_test['SkinThickness'], dy_preds, c='g', label='dy_preds')
plt.show()

# %% [markdown]
# ### Random Forest 회귀

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)
ry_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))
# Out:
# 평균제곱근오차 34.98007854868019

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_test['SkinThickness'], y_test, label='y_test')
plt.scatter(X_test['SkinThickness'], ry_preds, c='g', label='ry_preds')
plt.show()

# %% [markdown]
# ### SVR 회귀

# %%
from sklearn.svm import SVR

model = SVR(kernel='linear')
model.fit(X_train, y_train)
ry_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))
# Out:
# 평균제곱근오차 34.02407731924882

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_test['SkinThickness'], y_test, label='y_test')
plt.scatter(X_test['SkinThickness'], ry_preds, c='g', label='ly_preds')
plt.show()

# %% [markdown]
# ## 4. 3번과 동일하지만 dense layer만 사용한 신경만으로 회귀를 수행하라.

# %%
Y = pd.get_dummies(y).values
Y
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
X = X.values
X
# Out:
# array([[0.5       , 0.5       ],
#        [0.39285714, 0.41176471],
#        [0.28571429, 0.41176471],
#        ...,
#        [0.35714286, 0.47058824],
#        [0.28571429, 0.5       ],
#        [0.42857143, 0.47058824]])

# %%
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam

model = Sequential()

model.add(Dense(8,input_shape=(2,),activation='tanh'))
model.add(Dense(30,activation='tanh'))
model.add(Dense(30,activation='tanh'))
model.add(Dense(1))

model.compile(optimizer = 'rmsprop', loss = 'mse', metrics = ['mse'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 8)                 24
#
#  dense_9 (Dense)             (None, 30)                270
#
#  dense_10 (Dense)            (None, 30)                930
#
#  dense_11 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 1,255
# Trainable params: 1,255
# Non-trainable params: 0
# _________________________________________________________________

# %%
N_EPOCHS = 20

history=model.fit(x=X_train, y=y_train, epochs=N_EPOCHS, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)
# Out:
# Epoch 1/20
# 14/14 [==============================] - 2s 30ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 2/20
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 3/20
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 4/20
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 5/20
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 6/20
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 7/20
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 8/20
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 9/20
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 10/20
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 11/20
# 14/14 [==============================] - 1s 51ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 12/20
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 13/20
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 14/20
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 15/20
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 16/20
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 17/20
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 18/20
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 19/20
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 20/20
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# 4/4 [==============================] - 0s 2ms/step

# %%
plt.figure(figsize=(10,7))
plt.plot(range(N_EPOCHS), history.history['loss'], label='train loss')
plt.plot(range(N_EPOCHS), history.history['val_loss'], label='test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0049 - mse: 0.0049
# [0.0048586297780275345, 0.0048586297780275345]
